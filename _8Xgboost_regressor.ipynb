# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RandomizedSearchCV
from sklearn import metrics
import pickle
import warnings
warnings.filterwarnings('ignore')

# %%
X_train = pd.read_csv('Data/Train_Test/X_train.csv').to_numpy()
y_train = pd.read_csv('Data/Train_Test/y_train.csv').to_numpy()
X_test = pd.read_csv('Data/Train_Test/X_test.csv').to_numpy()
y_test = pd.read_csv('Data/Train_Test/y_test.csv').to_numpy()

# %%
xgb_reg = xgb.XGBRegressor()
xgb_reg.fit(X_train,y_train)
# Out:
# [17:59:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor()

# %%
print("Coefficient of determination R^2 <-- on train set: {}".format(xgb_reg.score(X_train, y_train)))
# Out:
# Coefficient of determination R^2 <-- on train set: 0.6564937452114477

# %%
print("Coefficient of determination R^2 <-- on test set: {}".format(xgb_reg.score(X_test, y_test)))
# Out:
# Coefficient of determination R^2 <-- on test set: 0.3325865485939371

# %%
mse = cross_val_score(xgb_reg,X_train,y_train,cv=5)
mean_mse = mse.mean()
print(mean_mse)
# Out:
# [17:59:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:59:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:59:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:59:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:59:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 0.4019146319077958

# %%
pred = xgb_reg.predict(X_test)

# %%
sns.distplot(y_test-pred)

# %%
plt.scatter(y_test,pred)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 49.321530591229056
# MSE: 4553.203459231623
# RMSE: 67.47742925772752

# %% [markdown]
# ### Hyperparameter tunning using Random Forest

# %%
xgb.XGBRegressor()
# Out:
# XGBRegressor()

# %%
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]

learning_rate = ['0.05','0.1', '0.2','0.3','0.5','0.6']

max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]

subsample=[0.7,0.6,0.8]

min_child_weight=[3,4,5,6,7]

# %%
random_grid = {'n_estimators': n_estimators,
               'learning_rate': learning_rate,
               'max_depth': max_depth,
               'subsample': subsample,
               'min_child_weight': min_child_weight}

# %%
xgb_reg = xgb.XGBRegressor()
xgb_regressor = RandomizedSearchCV(xgb_reg,param_distributions=random_grid,scoring='neg_mean_squared_error',n_iter=100,cv = 5,verbose=2,random_state=2,n_jobs=1)

# %%
xgb_regressor.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] subsample=0.6, n_estimators=900, min_child_weight=5, max_depth=25, learning_rate=0.3
# [17:59:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  subsample=0.6, n_estimators=900, min_child_weight=5, max_depth=25, learning_rate=0.3, total=   1.4s
# [CV] subsample=0.6, n_estimators=900, min_child_weight=5, max_depth=25, learning_rate=0.3
# [17:59:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s remaining:    0.0s
# [CV]  subsample=0.6, n_estimators=900, min_child_weight=5, max_depth=25, learning_rate=0.3, total=   1.0s
# [CV] subsample=0.6, n_estimators=900, min_child_weight=5, max_depth=25, learning_rate=0.3
# [17:59:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=900, min_child_weight=5, max_depth=25, learning_rate=0.3, total=   1.2s
# [CV] subsample=0.6, n_estimators=900, min_child_weight=5, max_depth=25, learning_rate=0.3
# [17:59:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=900, min_child_weight=5, max_depth=25, learning_rate=0.3, total=   1.0s
# [CV] subsample=0.6, n_estimators=900, min_child_weight=5, max_depth=25, learning_rate=0.3
# [17:59:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=900, min_child_weight=5, max_depth=25, learning_rate=0.3, total=   1.2s
# [CV] subsample=0.8, n_estimators=1200, min_child_weight=6, max_depth=20, learning_rate=0.05
# [17:59:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=1200, min_child_weight=6, max_depth=20, learning_rate=0.05, total=   1.8s
# [CV] subsample=0.8, n_estimators=1200, min_child_weight=6, max_depth=20, learning_rate=0.05
# [17:59:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=1200, min_child_weight=6, max_depth=20, learning_rate=0.05, total=   1.7s
# [CV] subsample=0.8, n_estimators=1200, min_child_weight=6, max_depth=20, learning_rate=0.05
# [17:59:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=1200, min_child_weight=6, max_depth=20, learning_rate=0.05, total=   1.7s
# [CV] subsample=0.8, n_estimators=1200, min_child_weight=6, max_depth=20, learning_rate=0.05
# [17:59:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=1200, min_child_weight=6, max_depth=20, learning_rate=0.05, total=   1.7s
# [CV] subsample=0.8, n_estimators=1200, min_child_weight=6, max_depth=20, learning_rate=0.05
# [17:59:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=1200, min_child_weight=6, max_depth=20, learning_rate=0.05, total=   1.6s
# [CV] subsample=0.7, n_estimators=300, min_child_weight=3, max_depth=10, learning_rate=0.05
# [17:59:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=300, min_child_weight=3, max_depth=10, learning_rate=0.05, total=   0.3s
# [CV] subsample=0.7, n_estimators=300, min_child_weight=3, max_depth=10, learning_rate=0.05
# [17:59:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=300, min_child_weight=3, max_depth=10, learning_rate=0.05, total=   0.3s
# [CV] subsample=0.7, n_estimators=300, min_child_weight=3, max_depth=10, learning_rate=0.05
# [17:59:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=300, min_child_weight=3, max_depth=10, learning_rate=0.05, total=   0.3s
# [CV] subsample=0.7, n_estimators=300, min_child_weight=3, max_depth=10, learning_rate=0.05
# [17:59:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=300, min_child_weight=3, max_depth=10, learning_rate=0.05, total=   0.3s
# [CV] subsample=0.7, n_estimators=300, min_child_weight=3, max_depth=10, learning_rate=0.05
# [17:59:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=300, min_child_weight=3, max_depth=10, learning_rate=0.05, total=   0.3s
# [CV] subsample=0.6, n_estimators=900, min_child_weight=4, max_depth=20, learning_rate=0.2
# [17:59:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=900, min_child_weight=4, max_depth=20, learning_rate=0.2, total=   1.1s
# [CV] subsample=0.6, n_estimators=900, min_child_weight=4, max_depth=20, learning_rate=0.2
# [17:59:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=900, min_child_weight=4, max_depth=20, learning_rate=0.2, total=   1.0s
# [CV] subsample=0.6, n_estimators=900, min_child_weight=4, max_depth=20, learning_rate=0.2
# [17:59:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=900, min_child_weight=4, max_depth=20, learning_rate=0.2, total=   1.1s
# [CV] subsample=0.6, n_estimators=900, min_child_weight=4, max_depth=20, learning_rate=0.2
# [17:59:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=900, min_child_weight=4, max_depth=20, learning_rate=0.2, total=   1.1s
# [CV] subsample=0.6, n_estimators=900, min_child_weight=4, max_depth=20, learning_rate=0.2
# [17:59:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=900, min_child_weight=4, max_depth=20, learning_rate=0.2, total=   1.2s
# [CV] subsample=0.8, n_estimators=700, min_child_weight=3, max_depth=5, learning_rate=0.1
# [17:59:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=700, min_child_weight=3, max_depth=5, learning_rate=0.1, total=   0.3s
# [CV] subsample=0.8, n_estimators=700, min_child_weight=3, max_depth=5, learning_rate=0.1
# [17:59:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=700, min_child_weight=3, max_depth=5, learning_rate=0.1, total=   0.3s
# [CV] subsample=0.8, n_estimators=700, min_child_weight=3, max_depth=5, learning_rate=0.1
# [17:59:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=700, min_child_weight=3, max_depth=5, learning_rate=0.1, total=   0.5s
# [CV] subsample=0.8, n_estimators=700, min_child_weight=3, max_depth=5, learning_rate=0.1
# [17:59:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=700, min_child_weight=3, max_depth=5, learning_rate=0.1, total=   0.3s
# [CV] subsample=0.8, n_estimators=700, min_child_weight=3, max_depth=5, learning_rate=0.1
# [17:59:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=700, min_child_weight=3, max_depth=5, learning_rate=0.1, total=   0.3s
# [CV] subsample=0.7, n_estimators=800, min_child_weight=7, max_depth=30, learning_rate=0.6
# [17:59:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=800, min_child_weight=7, max_depth=30, learning_rate=0.6, total=   1.3s
# [CV] subsample=0.7, n_estimators=800, min_child_weight=7, max_depth=30, learning_rate=0.6
# [17:59:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=800, min_child_weight=7, max_depth=30, learning_rate=0.6, total=   0.9s
# [CV] subsample=0.7, n_estimators=800, min_child_weight=7, max_depth=30, learning_rate=0.6
# [17:59:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=800, min_child_weight=7, max_depth=30, learning_rate=0.6, total=   1.3s
# [CV] subsample=0.7, n_estimators=800, min_child_weight=7, max_depth=30, learning_rate=0.6
# [17:59:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=800, min_child_weight=7, max_depth=30, learning_rate=0.6, total=   0.9s
# [CV] subsample=0.7, n_estimators=800, min_child_weight=7, max_depth=30, learning_rate=0.6
# [17:59:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=800, min_child_weight=7, max_depth=30, learning_rate=0.6, total=   0.9s
# [CV] subsample=0.8, n_estimators=1000, min_child_weight=4, max_depth=20, learning_rate=0.1
# [17:59:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=1000, min_child_weight=4, max_depth=20, learning_rate=0.1, total=   1.4s
# [CV] subsample=0.8, n_estimators=1000, min_child_weight=4, max_depth=20, learning_rate=0.1
# [17:59:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=1000, min_child_weight=4, max_depth=20, learning_rate=0.1, total=   1.2s
# [CV] subsample=0.8, n_estimators=1000, min_child_weight=4, max_depth=20, learning_rate=0.1
# [17:59:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=1000, min_child_weight=4, max_depth=20, learning_rate=0.1, total=   1.3s
# [CV] subsample=0.8, n_estimators=1000, min_child_weight=4, max_depth=20, learning_rate=0.1
# [17:59:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=1000, min_child_weight=4, max_depth=20, learning_rate=0.1, total=   1.4s
# [CV] subsample=0.8, n_estimators=1000, min_child_weight=4, max_depth=20, learning_rate=0.1
# [17:59:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=1000, min_child_weight=4, max_depth=20, learning_rate=0.1, total=   1.4s
# [CV] subsample=0.6, n_estimators=1200, min_child_weight=3, max_depth=5, learning_rate=0.2
# [17:59:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=1200, min_child_weight=3, max_depth=5, learning_rate=0.2, total=   0.6s
# [CV] subsample=0.6, n_estimators=1200, min_child_weight=3, max_depth=5, learning_rate=0.2
# [17:59:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=1200, min_child_weight=3, max_depth=5, learning_rate=0.2, total=   0.6s
# [CV] subsample=0.6, n_estimators=1200, min_child_weight=3, max_depth=5, learning_rate=0.2
# [17:59:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=1200, min_child_weight=3, max_depth=5, learning_rate=0.2, total=   0.6s
# [CV] subsample=0.6, n_estimators=1200, min_child_weight=3, max_depth=5, learning_rate=0.2
# [17:59:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=1200, min_child_weight=3, max_depth=5, learning_rate=0.2, total=   0.6s
# [CV] subsample=0.6, n_estimators=1200, min_child_weight=3, max_depth=5, learning_rate=0.2
# [17:59:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=1200, min_child_weight=3, max_depth=5, learning_rate=0.2, total=   0.6s
# [CV] subsample=0.7, n_estimators=100, min_child_weight=5, max_depth=15, learning_rate=0.3
# [17:59:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=100, min_child_weight=5, max_depth=15, learning_rate=0.3, total=   0.1s
# [CV] subsample=0.7, n_estimators=100, min_child_weight=5, max_depth=15, learning_rate=0.3
# [17:59:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=100, min_child_weight=5, max_depth=15, learning_rate=0.3, total=   0.1s
# [CV] subsample=0.7, n_estimators=100, min_child_weight=5, max_depth=15, learning_rate=0.3
# [17:59:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=100, min_child_weight=5, max_depth=15, learning_rate=0.3, total=   0.1s
# [CV] subsample=0.7, n_estimators=100, min_child_weight=5, max_depth=15, learning_rate=0.3
# [17:59:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=100, min_child_weight=5, max_depth=15, learning_rate=0.3, total=   0.1s
# [CV] subsample=0.7, n_estimators=100, min_child_weight=5, max_depth=15, learning_rate=0.3
# [17:59:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=100, min_child_weight=5, max_depth=15, learning_rate=0.3, total=   0.1s
# [CV] subsample=0.7, n_estimators=200, min_child_weight=3, max_depth=25, learning_rate=0.3
# [17:59:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=200, min_child_weight=3, max_depth=25, learning_rate=0.3, total=   0.3s
# [CV] subsample=0.7, n_estimators=200, min_child_weight=3, max_depth=25, learning_rate=0.3
# [17:59:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=200, min_child_weight=3, max_depth=25, learning_rate=0.3, total=   0.3s
# [CV] subsample=0.7, n_estimators=200, min_child_weight=3, max_depth=25, learning_rate=0.3
# [17:59:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=200, min_child_weight=3, max_depth=25, learning_rate=0.3, total=   0.3s
# [CV] subsample=0.7, n_estimators=200, min_child_weight=3, max_depth=25, learning_rate=0.3
# [17:59:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=200, min_child_weight=3, max_depth=25, learning_rate=0.3, total=   0.3s
# [CV] subsample=0.7, n_estimators=200, min_child_weight=3, max_depth=25, learning_rate=0.3
# [17:59:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=200, min_child_weight=3, max_depth=25, learning_rate=0.3, total=   0.3s
# [CV] subsample=0.6, n_estimators=400, min_child_weight=4, max_depth=5, learning_rate=0.5
# [17:59:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=400, min_child_weight=4, max_depth=5, learning_rate=0.5, total=   0.2s
# [CV] subsample=0.6, n_estimators=400, min_child_weight=4, max_depth=5, learning_rate=0.5
# [17:59:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=400, min_child_weight=4, max_depth=5, learning_rate=0.5, total=   0.2s
# [CV] subsample=0.6, n_estimators=400, min_child_weight=4, max_depth=5, learning_rate=0.5
# [17:59:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=400, min_child_weight=4, max_depth=5, learning_rate=0.5, total=   0.2s
# [CV] subsample=0.6, n_estimators=400, min_child_weight=4, max_depth=5, learning_rate=0.5
# [17:59:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=400, min_child_weight=4, max_depth=5, learning_rate=0.5, total=   0.2s
# [CV] subsample=0.6, n_estimators=400, min_child_weight=4, max_depth=5, learning_rate=0.5
# [17:59:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=400, min_child_weight=4, max_depth=5, learning_rate=0.5, total=   0.2s
# [CV] subsample=0.7, n_estimators=300, min_child_weight=3, max_depth=15, learning_rate=0.1
# [17:59:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=300, min_child_weight=3, max_depth=15, learning_rate=0.1, total=   0.4s
# [CV] subsample=0.7, n_estimators=300, min_child_weight=3, max_depth=15, learning_rate=0.1
# [17:59:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=300, min_child_weight=3, max_depth=15, learning_rate=0.1, total=   0.4s
# [CV] subsample=0.7, n_estimators=300, min_child_weight=3, max_depth=15, learning_rate=0.1
# [17:59:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=300, min_child_weight=3, max_depth=15, learning_rate=0.1, total=   0.4s
# [CV] subsample=0.7, n_estimators=300, min_child_weight=3, max_depth=15, learning_rate=0.1
# [17:59:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=300, min_child_weight=3, max_depth=15, learning_rate=0.1, total=   0.4s
# [CV] subsample=0.7, n_estimators=300, min_child_weight=3, max_depth=15, learning_rate=0.1
# [17:59:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=300, min_child_weight=3, max_depth=15, learning_rate=0.1, total=   0.4s
# [CV] subsample=0.8, n_estimators=700, min_child_weight=6, max_depth=25, learning_rate=0.1
# [17:59:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=700, min_child_weight=6, max_depth=25, learning_rate=0.1, total=   1.0s
# [CV] subsample=0.8, n_estimators=700, min_child_weight=6, max_depth=25, learning_rate=0.1
# [17:59:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=700, min_child_weight=6, max_depth=25, learning_rate=0.1, total=   0.9s
# [CV] subsample=0.8, n_estimators=700, min_child_weight=6, max_depth=25, learning_rate=0.1
# [17:59:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=700, min_child_weight=6, max_depth=25, learning_rate=0.1, total=   1.0s
# [CV] subsample=0.8, n_estimators=700, min_child_weight=6, max_depth=25, learning_rate=0.1
# [17:59:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=700, min_child_weight=6, max_depth=25, learning_rate=0.1, total=   1.0s
# [CV] subsample=0.8, n_estimators=700, min_child_weight=6, max_depth=25, learning_rate=0.1
# [17:59:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=700, min_child_weight=6, max_depth=25, learning_rate=0.1, total=   1.0s
# [CV] subsample=0.6, n_estimators=1100, min_child_weight=3, max_depth=5, learning_rate=0.1
# [17:59:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=1100, min_child_weight=3, max_depth=5, learning_rate=0.1, total=   0.5s
# [CV] subsample=0.6, n_estimators=1100, min_child_weight=3, max_depth=5, learning_rate=0.1
# [17:59:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=1100, min_child_weight=3, max_depth=5, learning_rate=0.1, total=   0.5s
# [CV] subsample=0.6, n_estimators=1100, min_child_weight=3, max_depth=5, learning_rate=0.1
# [17:59:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=1100, min_child_weight=3, max_depth=5, learning_rate=0.1, total=   0.5s
# [CV] subsample=0.6, n_estimators=1100, min_child_weight=3, max_depth=5, learning_rate=0.1
# [17:59:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=1100, min_child_weight=3, max_depth=5, learning_rate=0.1, total=   0.5s
# [CV] subsample=0.6, n_estimators=1100, min_child_weight=3, max_depth=5, learning_rate=0.1
# [17:59:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=1100, min_child_weight=3, max_depth=5, learning_rate=0.1, total=   0.5s
# [CV] subsample=0.6, n_estimators=800, min_child_weight=6, max_depth=15, learning_rate=0.2
# [17:59:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=800, min_child_weight=6, max_depth=15, learning_rate=0.2, total=   0.8s
# [CV] subsample=0.6, n_estimators=800, min_child_weight=6, max_depth=15, learning_rate=0.2
# [17:59:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=800, min_child_weight=6, max_depth=15, learning_rate=0.2, total=   0.8s
# [CV] subsample=0.6, n_estimators=800, min_child_weight=6, max_depth=15, learning_rate=0.2
# [17:59:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=800, min_child_weight=6, max_depth=15, learning_rate=0.2, total=   0.8s
# [CV] subsample=0.6, n_estimators=800, min_child_weight=6, max_depth=15, learning_rate=0.2
# [17:59:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=800, min_child_weight=6, max_depth=15, learning_rate=0.2, total=   0.8s
# [CV] subsample=0.6, n_estimators=800, min_child_weight=6, max_depth=15, learning_rate=0.2
# [17:59:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=800, min_child_weight=6, max_depth=15, learning_rate=0.2, total=   0.8s
# [CV] subsample=0.6, n_estimators=700, min_child_weight=3, max_depth=10, learning_rate=0.1
# [17:59:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=700, min_child_weight=3, max_depth=10, learning_rate=0.1, total=   0.6s
# [CV] subsample=0.6, n_estimators=700, min_child_weight=3, max_depth=10, learning_rate=0.1
# [17:59:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=700, min_child_weight=3, max_depth=10, learning_rate=0.1, total=   0.7s
# [CV] subsample=0.6, n_estimators=700, min_child_weight=3, max_depth=10, learning_rate=0.1
# [17:59:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=700, min_child_weight=3, max_depth=10, learning_rate=0.1, total=   0.6s
# [CV] subsample=0.6, n_estimators=700, min_child_weight=3, max_depth=10, learning_rate=0.1
# [17:59:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=700, min_child_weight=3, max_depth=10, learning_rate=0.1, total=   0.6s
# [CV] subsample=0.6, n_estimators=700, min_child_weight=3, max_depth=10, learning_rate=0.1
# [18:00:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=700, min_child_weight=3, max_depth=10, learning_rate=0.1, total=   0.6s
# [CV] subsample=0.6, n_estimators=1000, min_child_weight=7, max_depth=25, learning_rate=0.1
# [18:00:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=1000, min_child_weight=7, max_depth=25, learning_rate=0.1, total=   1.1s
# [CV] subsample=0.6, n_estimators=1000, min_child_weight=7, max_depth=25, learning_rate=0.1
# [18:00:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=1000, min_child_weight=7, max_depth=25, learning_rate=0.1, total=   1.1s
# [CV] subsample=0.6, n_estimators=1000, min_child_weight=7, max_depth=25, learning_rate=0.1
# [18:00:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=1000, min_child_weight=7, max_depth=25, learning_rate=0.1, total=   1.1s
# [CV] subsample=0.6, n_estimators=1000, min_child_weight=7, max_depth=25, learning_rate=0.1
# [18:00:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=1000, min_child_weight=7, max_depth=25, learning_rate=0.1, total=   1.0s
# [CV] subsample=0.6, n_estimators=1000, min_child_weight=7, max_depth=25, learning_rate=0.1
# [18:00:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=1000, min_child_weight=7, max_depth=25, learning_rate=0.1, total=   1.1s
# [CV] subsample=0.7, n_estimators=600, min_child_weight=5, max_depth=25, learning_rate=0.5
# [18:00:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=600, min_child_weight=5, max_depth=25, learning_rate=0.5, total=   0.6s
# [CV] subsample=0.7, n_estimators=600, min_child_weight=5, max_depth=25, learning_rate=0.5
# [18:00:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=600, min_child_weight=5, max_depth=25, learning_rate=0.5, total=   0.7s
# [CV] subsample=0.7, n_estimators=600, min_child_weight=5, max_depth=25, learning_rate=0.5
# [18:00:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=600, min_child_weight=5, max_depth=25, learning_rate=0.5, total=   0.6s
# [CV] subsample=0.7, n_estimators=600, min_child_weight=5, max_depth=25, learning_rate=0.5
# [18:00:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=600, min_child_weight=5, max_depth=25, learning_rate=0.5, total=   0.6s
# [CV] subsample=0.7, n_estimators=600, min_child_weight=5, max_depth=25, learning_rate=0.5
# [18:00:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=600, min_child_weight=5, max_depth=25, learning_rate=0.5, total=   0.7s
# [CV] subsample=0.6, n_estimators=800, min_child_weight=5, max_depth=10, learning_rate=0.3
# [18:00:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=800, min_child_weight=5, max_depth=10, learning_rate=0.3, total=   0.6s
# [CV] subsample=0.6, n_estimators=800, min_child_weight=5, max_depth=10, learning_rate=0.3
# [18:00:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=800, min_child_weight=5, max_depth=10, learning_rate=0.3, total=   0.6s
# [CV] subsample=0.6, n_estimators=800, min_child_weight=5, max_depth=10, learning_rate=0.3
# [18:00:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=800, min_child_weight=5, max_depth=10, learning_rate=0.3, total=   0.6s
# [CV] subsample=0.6, n_estimators=800, min_child_weight=5, max_depth=10, learning_rate=0.3
# [18:00:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=800, min_child_weight=5, max_depth=10, learning_rate=0.3, total=   0.6s
# [CV] subsample=0.6, n_estimators=800, min_child_weight=5, max_depth=10, learning_rate=0.3
# [18:00:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=800, min_child_weight=5, max_depth=10, learning_rate=0.3, total=   0.6s
# [CV] subsample=0.6, n_estimators=400, min_child_weight=4, max_depth=20, learning_rate=0.3
# [18:00:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=400, min_child_weight=4, max_depth=20, learning_rate=0.3, total=   0.5s
# [CV] subsample=0.6, n_estimators=400, min_child_weight=4, max_depth=20, learning_rate=0.3
# [18:00:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=400, min_child_weight=4, max_depth=20, learning_rate=0.3, total=   0.5s
# [CV] subsample=0.6, n_estimators=400, min_child_weight=4, max_depth=20, learning_rate=0.3
# [18:00:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=400, min_child_weight=4, max_depth=20, learning_rate=0.3, total=   0.6s
# [CV] subsample=0.6, n_estimators=400, min_child_weight=4, max_depth=20, learning_rate=0.3
# [18:00:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=400, min_child_weight=4, max_depth=20, learning_rate=0.3, total=   0.6s
# [CV] subsample=0.6, n_estimators=400, min_child_weight=4, max_depth=20, learning_rate=0.3
# [18:00:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=400, min_child_weight=4, max_depth=20, learning_rate=0.3, total=   0.5s
# [CV] subsample=0.8, n_estimators=600, min_child_weight=3, max_depth=25, learning_rate=0.1
# [18:00:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=600, min_child_weight=3, max_depth=25, learning_rate=0.1, total=   1.0s
# [CV] subsample=0.8, n_estimators=600, min_child_weight=3, max_depth=25, learning_rate=0.1
# [18:00:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=600, min_child_weight=3, max_depth=25, learning_rate=0.1, total=   0.9s
# [CV] subsample=0.8, n_estimators=600, min_child_weight=3, max_depth=25, learning_rate=0.1
# [18:00:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=600, min_child_weight=3, max_depth=25, learning_rate=0.1, total=   1.0s
# [CV] subsample=0.8, n_estimators=600, min_child_weight=3, max_depth=25, learning_rate=0.1
# [18:00:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=600, min_child_weight=3, max_depth=25, learning_rate=0.1, total=   1.0s
# [CV] subsample=0.8, n_estimators=600, min_child_weight=3, max_depth=25, learning_rate=0.1
# [18:00:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=600, min_child_weight=3, max_depth=25, learning_rate=0.1, total=   1.1s
# [CV] subsample=0.6, n_estimators=100, min_child_weight=7, max_depth=5, learning_rate=0.05
# [18:00:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=100, min_child_weight=7, max_depth=5, learning_rate=0.05, total=   0.0s
# [CV] subsample=0.6, n_estimators=100, min_child_weight=7, max_depth=5, learning_rate=0.05
# [18:00:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=100, min_child_weight=7, max_depth=5, learning_rate=0.05, total=   0.0s
# [CV] subsample=0.6, n_estimators=100, min_child_weight=7, max_depth=5, learning_rate=0.05
# [18:00:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=100, min_child_weight=7, max_depth=5, learning_rate=0.05, total=   0.0s
# [CV] subsample=0.6, n_estimators=100, min_child_weight=7, max_depth=5, learning_rate=0.05
# [18:00:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=100, min_child_weight=7, max_depth=5, learning_rate=0.05, total=   0.1s
# [CV] subsample=0.6, n_estimators=100, min_child_weight=7, max_depth=5, learning_rate=0.05
# [18:00:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=100, min_child_weight=7, max_depth=5, learning_rate=0.05, total=   0.1s
# [CV] subsample=0.7, n_estimators=600, min_child_weight=7, max_depth=5, learning_rate=0.3
# [18:00:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=600, min_child_weight=7, max_depth=5, learning_rate=0.3, total=   0.3s
# [CV] subsample=0.7, n_estimators=600, min_child_weight=7, max_depth=5, learning_rate=0.3
# [18:00:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=600, min_child_weight=7, max_depth=5, learning_rate=0.3, total=   0.3s
# [CV] subsample=0.7, n_estimators=600, min_child_weight=7, max_depth=5, learning_rate=0.3
# [18:00:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=600, min_child_weight=7, max_depth=5, learning_rate=0.3, total=   0.3s
# [CV] subsample=0.7, n_estimators=600, min_child_weight=7, max_depth=5, learning_rate=0.3
# [18:00:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=600, min_child_weight=7, max_depth=5, learning_rate=0.3, total=   0.3s
# [CV] subsample=0.7, n_estimators=600, min_child_weight=7, max_depth=5, learning_rate=0.3
# [18:00:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=600, min_child_weight=7, max_depth=5, learning_rate=0.3, total=   0.3s
# [CV] subsample=0.8, n_estimators=800, min_child_weight=6, max_depth=5, learning_rate=0.6
# [18:00:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=800, min_child_weight=6, max_depth=5, learning_rate=0.6, total=   0.4s
# [CV] subsample=0.8, n_estimators=800, min_child_weight=6, max_depth=5, learning_rate=0.6
# [18:00:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=800, min_child_weight=6, max_depth=5, learning_rate=0.6, total=   0.4s
# [CV] subsample=0.8, n_estimators=800, min_child_weight=6, max_depth=5, learning_rate=0.6
# [18:00:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=800, min_child_weight=6, max_depth=5, learning_rate=0.6, total=   0.4s
# [CV] subsample=0.8, n_estimators=800, min_child_weight=6, max_depth=5, learning_rate=0.6
# [18:00:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=800, min_child_weight=6, max_depth=5, learning_rate=0.6, total=   0.4s
# [CV] subsample=0.8, n_estimators=800, min_child_weight=6, max_depth=5, learning_rate=0.6
# [18:00:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=800, min_child_weight=6, max_depth=5, learning_rate=0.6, total=   0.4s
# [CV] subsample=0.7, n_estimators=700, min_child_weight=5, max_depth=10, learning_rate=0.1
# [18:00:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=700, min_child_weight=5, max_depth=10, learning_rate=0.1, total=   0.6s
# [CV] subsample=0.7, n_estimators=700, min_child_weight=5, max_depth=10, learning_rate=0.1
# [18:00:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=700, min_child_weight=5, max_depth=10, learning_rate=0.1, total=   0.6s
# [CV] subsample=0.7, n_estimators=700, min_child_weight=5, max_depth=10, learning_rate=0.1
# [18:00:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=700, min_child_weight=5, max_depth=10, learning_rate=0.1, total=   0.6s
# [CV] subsample=0.7, n_estimators=700, min_child_weight=5, max_depth=10, learning_rate=0.1
# [18:00:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=700, min_child_weight=5, max_depth=10, learning_rate=0.1, total=   0.6s
# [CV] subsample=0.7, n_estimators=700, min_child_weight=5, max_depth=10, learning_rate=0.1
# [18:00:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=700, min_child_weight=5, max_depth=10, learning_rate=0.1, total=   0.6s
# [CV] subsample=0.8, n_estimators=100, min_child_weight=7, max_depth=30, learning_rate=0.1
# [18:00:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=100, min_child_weight=7, max_depth=30, learning_rate=0.1, total=   0.1s
# [CV] subsample=0.8, n_estimators=100, min_child_weight=7, max_depth=30, learning_rate=0.1
# [18:00:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=100, min_child_weight=7, max_depth=30, learning_rate=0.1, total=   0.1s
# [CV] subsample=0.8, n_estimators=100, min_child_weight=7, max_depth=30, learning_rate=0.1
# [18:00:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=100, min_child_weight=7, max_depth=30, learning_rate=0.1, total=   0.1s
# [CV] subsample=0.8, n_estimators=100, min_child_weight=7, max_depth=30, learning_rate=0.1
# [18:00:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=100, min_child_weight=7, max_depth=30, learning_rate=0.1, total=   0.1s
# [CV] subsample=0.8, n_estimators=100, min_child_weight=7, max_depth=30, learning_rate=0.1
# [18:00:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=100, min_child_weight=7, max_depth=30, learning_rate=0.1, total=   0.1s
# [CV] subsample=0.7, n_estimators=100, min_child_weight=6, max_depth=15, learning_rate=0.2
# [18:00:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=100, min_child_weight=6, max_depth=15, learning_rate=0.2, total=   0.1s
# [CV] subsample=0.7, n_estimators=100, min_child_weight=6, max_depth=15, learning_rate=0.2
# [18:00:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=100, min_child_weight=6, max_depth=15, learning_rate=0.2, total=   0.1s
# [CV] subsample=0.7, n_estimators=100, min_child_weight=6, max_depth=15, learning_rate=0.2
# [18:00:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=100, min_child_weight=6, max_depth=15, learning_rate=0.2, total=   0.1s
# [CV] subsample=0.7, n_estimators=100, min_child_weight=6, max_depth=15, learning_rate=0.2
# [18:00:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=100, min_child_weight=6, max_depth=15, learning_rate=0.2, total=   0.1s
# [CV] subsample=0.7, n_estimators=100, min_child_weight=6, max_depth=15, learning_rate=0.2
# [18:00:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=100, min_child_weight=6, max_depth=15, learning_rate=0.2, total=   0.1s
# [CV] subsample=0.6, n_estimators=400, min_child_weight=6, max_depth=25, learning_rate=0.1
# [18:00:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=400, min_child_weight=6, max_depth=25, learning_rate=0.1, total=   0.4s
# [CV] subsample=0.6, n_estimators=400, min_child_weight=6, max_depth=25, learning_rate=0.1
# [18:00:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=400, min_child_weight=6, max_depth=25, learning_rate=0.1, total=   0.4s
# [CV] subsample=0.6, n_estimators=400, min_child_weight=6, max_depth=25, learning_rate=0.1
# [18:00:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=400, min_child_weight=6, max_depth=25, learning_rate=0.1, total=   0.4s
# [CV] subsample=0.6, n_estimators=400, min_child_weight=6, max_depth=25, learning_rate=0.1
# [18:00:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=400, min_child_weight=6, max_depth=25, learning_rate=0.1, total=   0.4s
# [CV] subsample=0.6, n_estimators=400, min_child_weight=6, max_depth=25, learning_rate=0.1
# [18:00:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=400, min_child_weight=6, max_depth=25, learning_rate=0.1, total=   0.4s
# [CV] subsample=0.7, n_estimators=200, min_child_weight=6, max_depth=10, learning_rate=0.05
# [18:00:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=200, min_child_weight=6, max_depth=10, learning_rate=0.05, total=   0.2s
# [CV] subsample=0.7, n_estimators=200, min_child_weight=6, max_depth=10, learning_rate=0.05
# [18:00:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=200, min_child_weight=6, max_depth=10, learning_rate=0.05, total=   0.2s
# [CV] subsample=0.7, n_estimators=200, min_child_weight=6, max_depth=10, learning_rate=0.05
# [18:00:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=200, min_child_weight=6, max_depth=10, learning_rate=0.05, total=   0.2s
# [CV] subsample=0.7, n_estimators=200, min_child_weight=6, max_depth=10, learning_rate=0.05
# [18:00:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=200, min_child_weight=6, max_depth=10, learning_rate=0.05, total=   0.2s
# [CV] subsample=0.7, n_estimators=200, min_child_weight=6, max_depth=10, learning_rate=0.05
# [18:00:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.7, n_estimators=200, min_child_weight=6, max_depth=10, learning_rate=0.05, total=   0.2s
# [CV] subsample=0.8, n_estimators=600, min_child_weight=6, max_depth=30, learning_rate=0.3
# [18:00:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=600, min_child_weight=6, max_depth=30, learning_rate=0.3, total=   0.9s
# [CV] subsample=0.8, n_estimators=600, min_child_weight=6, max_depth=30, learning_rate=0.3
# [18:00:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=600, min_child_weight=6, max_depth=30, learning_rate=0.3, total=   0.7s
# [CV] subsample=0.8, n_estimators=600, min_child_weight=6, max_depth=30, learning_rate=0.3
# [18:00:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=600, min_child_weight=6, max_depth=30, learning_rate=0.3, total=   0.8s
# [CV] subsample=0.8, n_estimators=600, min_child_weight=6, max_depth=30, learning_rate=0.3
# [18:00:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=600, min_child_weight=6, max_depth=30, learning_rate=0.3, total=   0.8s
# [CV] subsample=0.8, n_estimators=600, min_child_weight=6, max_depth=30, learning_rate=0.3
# [18:00:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=600, min_child_weight=6, max_depth=30, learning_rate=0.3, total=   0.9s
# [CV] subsample=0.8, n_estimators=400, min_child_weight=6, max_depth=30, learning_rate=0.05
# [18:00:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=400, min_child_weight=6, max_depth=30, learning_rate=0.05, total=   0.5s
# [CV] subsample=0.8, n_estimators=400, min_child_weight=6, max_depth=30, learning_rate=0.05
# [18:00:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=400, min_child_weight=6, max_depth=30, learning_rate=0.05, total=   0.5s
# [CV] subsample=0.8, n_estimators=400, min_child_weight=6, max_depth=30, learning_rate=0.05
# ...
# [18:04:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=800, min_child_weight=7, max_depth=25, learning_rate=0.05, total=   1.2s
# [CV] subsample=0.8, n_estimators=800, min_child_weight=7, max_depth=25, learning_rate=0.05
# [18:04:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=800, min_child_weight=7, max_depth=25, learning_rate=0.05, total=   1.0s
# [CV] subsample=0.8, n_estimators=800, min_child_weight=7, max_depth=25, learning_rate=0.05
# [18:04:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=800, min_child_weight=7, max_depth=25, learning_rate=0.05, total=   1.1s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=3, max_depth=5, learning_rate=0.2
# [18:04:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=3, max_depth=5, learning_rate=0.2, total=   0.1s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=3, max_depth=5, learning_rate=0.2
# [18:04:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=3, max_depth=5, learning_rate=0.2, total=   0.1s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=3, max_depth=5, learning_rate=0.2
# [18:04:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=3, max_depth=5, learning_rate=0.2, total=   0.1s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=3, max_depth=5, learning_rate=0.2
# [18:04:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=3, max_depth=5, learning_rate=0.2, total=   0.1s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=3, max_depth=5, learning_rate=0.2
# [18:04:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=3, max_depth=5, learning_rate=0.2, total=   0.1s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=7, max_depth=30, learning_rate=0.1
# [18:04:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=7, max_depth=30, learning_rate=0.1, total=   0.3s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=7, max_depth=30, learning_rate=0.1
# [18:04:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=7, max_depth=30, learning_rate=0.1, total=   0.3s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=7, max_depth=30, learning_rate=0.1
# [18:04:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=7, max_depth=30, learning_rate=0.1, total=   0.3s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=7, max_depth=30, learning_rate=0.1
# [18:04:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=7, max_depth=30, learning_rate=0.1, total=   0.3s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=7, max_depth=30, learning_rate=0.1
# [18:04:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=7, max_depth=30, learning_rate=0.1, total=   0.3s
# [CV] subsample=0.6, n_estimators=900, min_child_weight=5, max_depth=10, learning_rate=0.6
# [18:04:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=900, min_child_weight=5, max_depth=10, learning_rate=0.6, total=   0.6s
# [CV] subsample=0.6, n_estimators=900, min_child_weight=5, max_depth=10, learning_rate=0.6
# [18:04:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=900, min_child_weight=5, max_depth=10, learning_rate=0.6, total=   0.5s
# [CV] subsample=0.6, n_estimators=900, min_child_weight=5, max_depth=10, learning_rate=0.6
# [18:04:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=900, min_child_weight=5, max_depth=10, learning_rate=0.6, total=   0.5s
# [CV] subsample=0.6, n_estimators=900, min_child_weight=5, max_depth=10, learning_rate=0.6
# [18:04:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=900, min_child_weight=5, max_depth=10, learning_rate=0.6, total=   0.6s
# [CV] subsample=0.6, n_estimators=900, min_child_weight=5, max_depth=10, learning_rate=0.6
# [18:04:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=900, min_child_weight=5, max_depth=10, learning_rate=0.6, total=   0.5s
# [CV] subsample=0.6, n_estimators=1200, min_child_weight=6, max_depth=25, learning_rate=0.05
# [18:04:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=1200, min_child_weight=6, max_depth=25, learning_rate=0.05, total=   1.4s
# [CV] subsample=0.6, n_estimators=1200, min_child_weight=6, max_depth=25, learning_rate=0.05
# [18:04:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=1200, min_child_weight=6, max_depth=25, learning_rate=0.05, total=   1.3s
# [CV] subsample=0.6, n_estimators=1200, min_child_weight=6, max_depth=25, learning_rate=0.05
# [18:04:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=1200, min_child_weight=6, max_depth=25, learning_rate=0.05, total=   1.3s
# [CV] subsample=0.6, n_estimators=1200, min_child_weight=6, max_depth=25, learning_rate=0.05
# [18:04:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=1200, min_child_weight=6, max_depth=25, learning_rate=0.05, total=   1.3s
# [CV] subsample=0.6, n_estimators=1200, min_child_weight=6, max_depth=25, learning_rate=0.05
# [18:04:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=1200, min_child_weight=6, max_depth=25, learning_rate=0.05, total=   1.4s
# [CV] subsample=0.8, n_estimators=1200, min_child_weight=5, max_depth=15, learning_rate=0.5
# [18:04:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=1200, min_child_weight=5, max_depth=15, learning_rate=0.5, total=   0.6s
# [CV] subsample=0.8, n_estimators=1200, min_child_weight=5, max_depth=15, learning_rate=0.5
# [18:04:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=1200, min_child_weight=5, max_depth=15, learning_rate=0.5, total=   0.4s
# [CV] subsample=0.8, n_estimators=1200, min_child_weight=5, max_depth=15, learning_rate=0.5
# [18:04:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=1200, min_child_weight=5, max_depth=15, learning_rate=0.5, total=   0.6s
# [CV] subsample=0.8, n_estimators=1200, min_child_weight=5, max_depth=15, learning_rate=0.5
# [18:04:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=1200, min_child_weight=5, max_depth=15, learning_rate=0.5, total=   0.5s
# [CV] subsample=0.8, n_estimators=1200, min_child_weight=5, max_depth=15, learning_rate=0.5
# [18:04:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=1200, min_child_weight=5, max_depth=15, learning_rate=0.5, total=   0.6s
# [CV] subsample=0.8, n_estimators=200, min_child_weight=3, max_depth=15, learning_rate=0.3
# [18:04:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=200, min_child_weight=3, max_depth=15, learning_rate=0.3, total=   0.2s
# [CV] subsample=0.8, n_estimators=200, min_child_weight=3, max_depth=15, learning_rate=0.3
# [18:04:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=200, min_child_weight=3, max_depth=15, learning_rate=0.3, total=   0.3s
# [CV] subsample=0.8, n_estimators=200, min_child_weight=3, max_depth=15, learning_rate=0.3
# [18:04:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=200, min_child_weight=3, max_depth=15, learning_rate=0.3, total=   0.2s
# [CV] subsample=0.8, n_estimators=200, min_child_weight=3, max_depth=15, learning_rate=0.3
# [18:04:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=200, min_child_weight=3, max_depth=15, learning_rate=0.3, total=   0.3s
# [CV] subsample=0.8, n_estimators=200, min_child_weight=3, max_depth=15, learning_rate=0.3
# [18:04:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=200, min_child_weight=3, max_depth=15, learning_rate=0.3, total=   0.2s
# [CV] subsample=0.8, n_estimators=1100, min_child_weight=6, max_depth=20, learning_rate=0.1
# [18:04:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=1100, min_child_weight=6, max_depth=20, learning_rate=0.1, total=   1.4s
# [CV] subsample=0.8, n_estimators=1100, min_child_weight=6, max_depth=20, learning_rate=0.1
# [18:04:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=1100, min_child_weight=6, max_depth=20, learning_rate=0.1, total=   1.4s
# [CV] subsample=0.8, n_estimators=1100, min_child_weight=6, max_depth=20, learning_rate=0.1
# [18:04:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=1100, min_child_weight=6, max_depth=20, learning_rate=0.1, total=   1.4s
# [CV] subsample=0.8, n_estimators=1100, min_child_weight=6, max_depth=20, learning_rate=0.1
# [18:04:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=1100, min_child_weight=6, max_depth=20, learning_rate=0.1, total=   1.5s
# [CV] subsample=0.8, n_estimators=1100, min_child_weight=6, max_depth=20, learning_rate=0.1
# [18:04:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.8, n_estimators=1100, min_child_weight=6, max_depth=20, learning_rate=0.1, total=   1.4s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=6, max_depth=20, learning_rate=0.1
# [18:04:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=6, max_depth=20, learning_rate=0.1, total=   0.3s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=6, max_depth=20, learning_rate=0.1
# [18:04:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=6, max_depth=20, learning_rate=0.1, total=   0.3s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=6, max_depth=20, learning_rate=0.1
# [18:04:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=6, max_depth=20, learning_rate=0.1, total=   0.3s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=6, max_depth=20, learning_rate=0.1
# [18:04:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=6, max_depth=20, learning_rate=0.1, total=   0.3s
# [CV] subsample=0.6, n_estimators=300, min_child_weight=6, max_depth=20, learning_rate=0.1
# [18:04:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=300, min_child_weight=6, max_depth=20, learning_rate=0.1, total=   0.3s
# [CV] subsample=0.6, n_estimators=400, min_child_weight=5, max_depth=5, learning_rate=0.1
# [18:04:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=400, min_child_weight=5, max_depth=5, learning_rate=0.1, total=   0.2s
# [CV] subsample=0.6, n_estimators=400, min_child_weight=5, max_depth=5, learning_rate=0.1
# [18:04:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=400, min_child_weight=5, max_depth=5, learning_rate=0.1, total=   0.2s
# [CV] subsample=0.6, n_estimators=400, min_child_weight=5, max_depth=5, learning_rate=0.1
# [18:04:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=400, min_child_weight=5, max_depth=5, learning_rate=0.1, total=   0.2s
# [CV] subsample=0.6, n_estimators=400, min_child_weight=5, max_depth=5, learning_rate=0.1
# [18:04:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=400, min_child_weight=5, max_depth=5, learning_rate=0.1, total=   0.2s
# [CV] subsample=0.6, n_estimators=400, min_child_weight=5, max_depth=5, learning_rate=0.1
# [18:04:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  subsample=0.6, n_estimators=400, min_child_weight=5, max_depth=5, learning_rate=0.1, total=   0.2s
# [18:04:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Done 500 out of 500 | elapsed:  5.5min finished
# RandomizedSearchCV(cv=5, estimator=XGBRegressor(), n_iter=100, n_jobs=1,
#                    param_distributions={'learning_rate': ['0.05', '0.1', '0.2',
#                                                           '0.3', '0.5', '0.6'],
#                                         'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'min_child_weight': [3, 4, 5, 6, 7],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100,
#                                                          1200],
#                                         'subsample': [0.7, 0.6, 0.8]},
#                    random_state=2, scoring='neg_mean_squared_error', verbose=2)

# %%
xgb_regressor.best_params_
# Out:
# {'subsample': 0.6,
#  'n_estimators': 100,
#  'min_child_weight': 7,
#  'max_depth': 5,
#  'learning_rate': '0.05'}

# %%
xgb_regressor.best_score_
# Out:
# -4047.4992845498427

# %%
pred = xgb_regressor.predict(X_test)

# %%
sns.distplot(y_test-pred)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 47.870592373543516
# MSE: 4431.41942577329
# RMSE: 66.56890735000304

# %%
# open a file, where you ant to store the data
file = open('xgboost_regressor.pkl', 'wb')

# dump information to that file
pickle.dump(xgb_regressor, file)
file.close()
